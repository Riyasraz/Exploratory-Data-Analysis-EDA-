# %% [markdown]
# # Exploratory Data Analysis(EDA)
# ### Providing a dataset of employees working in ABC company.it concists of 458 rows and 9 columns.The company needs the detailed report and explanation of their employees in each team.Here is the detailed analysis of the data which includes studying,exploring and visualizing information.The following are the variable belong to the dataset:
# #### *Name:Names of employees
#
# #### *Team:30 groups in which employees are divided
#
# #### *Number:Number assigned to the employees
#
# #### *Position:5 positions(PG,SG,SF,PF,C)
#
# #### *Age:Age of the employees
#
# #### *Height:The dataset provides dates in the place of height
#
# #### *Weight:Weight of employees
#
# #### *College:colleges og employees
#
# #### *Salary:Salaries of each employees #

# %% [markdown]
# ## Import necessary modules ##

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Creating a dataframe using a csv file(myexcel.csv) ##

# %%
df=pd.read_csv("D:\Jupyter Notebook\Project myexcel.csv.csv")
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# ## Data preprocessing to get the general insights regarding the data. ##

# %%
df.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1    Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27  06-May     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df.tail()
# Out:
#              Name       Team  Number Position  Age  Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz       8       PG   26  06-Mar     203  Butler
# 454     Raul Neto  Utah Jazz      25       PG   24  06-Jan     179     NaN
# 455  Tibor Pleiss  Utah Jazz      21        C   26  07-Mar     256     NaN
# 456   Jeff Withey  Utah Jazz      24        C   26     7-0     231  Kansas
# 457      Priyanka  Utah Jazz      34        C   25  07-Mar     231  Kansas
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457   947276.0

# %%
df.describe(include='all')
# Out:
#                  Name                  Team      Number Position         Age  \
# count             458                   458  458.000000      458  458.000000
# unique            458                    30         NaN        5         NaN
# top     Avery Bradley  New Orleans Pelicans         NaN       SG         NaN
# freq                1                    19         NaN      102         NaN
# mean              NaN                   NaN   17.713974      NaN   26.934498
# std               NaN                   NaN   15.966837      NaN    4.400128
# min               NaN                   NaN    0.000000      NaN   19.000000
# 25%               NaN                   NaN    5.000000      NaN   24.000000
# 50%               NaN                   NaN   13.000000      NaN   26.000000
# 75%               NaN                   NaN   25.000000      NaN   30.000000
# max               NaN                   NaN   99.000000      NaN   40.000000
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    object
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB

# %%
df.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
df.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 453    False
# 454    False
# 455    False
# 456    False
# 457    False
# Length: 458, dtype: bool

# %%
df.nunique()
# Out:
# Name        458
# Team         30
# Number       53
# Position      5
# Age          22
# Height       18
# Weight       87
# College     118
# Salary      309
# dtype: int64

# %%
df['Number']
# Out:
# 0       0
# 1      99
# 2      30
# 3      28
# 4       8
#        ..
# 453     8
# 454    25
# 455    21
# 456    24
# 457    34
# Name: Number, Length: 458, dtype: int64

# %% [markdown]
# #### Through Data preprocessing a raw data can be made into an understandable format.The head() function displays the top rows of dataframe while the tail() displays the bottom rows.info() prints information abt DF.descibe() returns description of the data.duplicated() returns a series with True and False values that describe which rows in the dataframe duplicated and not.
#
# #### *The dataset provides Dates instead of Heigh of the employees.So we have to correct it with the random height. #

# %%
df['Height']
# Out:
# 0      06-Feb
# 1      06-Jun
# 2      06-May
# 3      06-May
# 4      06-Oct
#         ...
# 453    06-Mar
# 454    06-Jan
# 455    07-Mar
# 456       7-0
# 457    07-Mar
# Name: Height, Length: 458, dtype: object

# %%
Height=np.random.randint(150,180,size=458)
df['Height']=Height
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     179     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     171     235
# 2     John Holland  Boston Celtics      30       SG   27     176     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     175     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     173     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     174     203
# 454      Raul Neto       Utah Jazz      25       PG   24     178     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     170     256
# 456    Jeff Withey       Utah Jazz      24        C   26     151     231
# 457       Priyanka       Utah Jazz      34        C   25     165     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# # 1.How many are there in each Team and the percentage splitting with respect to the total employees? #

# %%
df['Team'].value_counts()
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %%
df['Team'].value_counts()/len(df)*100
# Out:
# Team
# New Orleans Pelicans      4.148472
# Memphis Grizzlies         3.930131
# Utah Jazz                 3.493450
# New York Knicks           3.493450
# Milwaukee Bucks           3.493450
# Brooklyn Nets             3.275109
# Portland Trail Blazers    3.275109
# Oklahoma City Thunder     3.275109
# Denver Nuggets            3.275109
# Washington Wizards        3.275109
# Miami Heat                3.275109
# Charlotte Hornets         3.275109
# Atlanta Hawks             3.275109
# San Antonio Spurs         3.275109
# Houston Rockets           3.275109
# Boston Celtics            3.275109
# Indiana Pacers            3.275109
# Detroit Pistons           3.275109
# Cleveland Cavaliers       3.275109
# Chicago Bulls             3.275109
# Sacramento Kings          3.275109
# Phoenix Suns              3.275109
# Los Angeles Lakers        3.275109
# Los Angeles Clippers      3.275109
# Golden State Warriors     3.275109
# Toronto Raptors           3.275109
# ...

# %%
#visualize the data
import matplotlib.pyplot as plt
colors=['blue','green','red','violet','orange']
plt.bar(total_emp.index,total_emp.values,color=colors)
# Customize the plot
plt.xlabel('Team')
plt.ylabel('Percentage')
plt.title('Percentage Splitting of Employees w.r.t each Team')
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# #### It is clear that Team "New Orleans Pelicans" has the highest percentage of employees belongs to.other Team have almost the same percentage.Consequently,the splitting percentage, or the proportion of the total workforce,is also highest for these respective Team.The bar plot is used to plot the same data which illustrates the percentage splitting with respect to the employees #

# %% [markdown]
# ## 2.Seggregate the employees w.r.t different position? ##

# %%
df['Position'].value_counts()
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %%
df[['Position','Name']]
# Out:
#     Position           Name
# 0         PG  Avery Bradley
# 1         SF    Jae Crowder
# 2         SG   John Holland
# 3         SG    R.J. Hunter
# 4         PF  Jonas Jerebko
# ..       ...            ...
# 453       PG   Shelvin Mack
# 454       PG      Raul Neto
# 455        C   Tibor Pleiss
# 456        C    Jeff Withey
# 457        C       Priyanka
#
# [458 rows x 2 columns]

# %%
#seggregating employees w.r.t different position
#display with only name and position

grouped_by_position=df.groupby('Position')
for position,group in grouped_by_position:
    print(f"Position:{position}")
    print(group[['Name','Position']])
    print("\n")
# Out:
# Position:C
#                 Name Position
# 7       Kelly Olynyk        C
# 10   Jared Sullinger        C
# 14      Tyler Zeller        C
# 23       Brook Lopez        C
# 27        Henry Sims        C
# ..               ...      ...
# 439    Mason Plumlee        C
# 447      Rudy Gobert        C
# 455     Tibor Pleiss        C
# 456      Jeff Withey        C
# 457         Priyanka        C
#
# [79 rows x 2 columns]
#
#
# Position:PF
#                  Name Position
# 4       Jonas Jerebko       PF
# 5        Amir Johnson       PF
# 6       Jordan Mickey       PF
# 24   Chris McCullough       PF
# 25        Willie Reed       PF
# ..                ...      ...
# 435    Meyers Leonard       PF
# 441       Noah Vonleh       PF
# 442     Trevor Booker       PF
# 446    Derrick Favors       PF
# 452        Trey Lyles       PF
#
# [100 rows x 2 columns]
#
#
# Position:PG
#               Name Position
# 0    Avery Bradley       PG
# 8     Terry Rozier       PG
# ...

# %%
unique_positions=df['Position'].unique()
print("unique positions:",unique_positions)
plt.figure(figsize=(7,5))
plt.title('seggregate Employee by position')
sns.countplot(x='Position', data=df,hue='Position', palette='viridis')
# Out:
# unique positions: ['PG' 'SF' 'SG' 'PF' 'C']
# <Axes: title={'center': 'seggregate Employee by position'}, xlabel='Position', ylabel='count'>

# %% [markdown]
# #### By analysing the above countplot,it is clear that,the most number of employees are belong to 'SG' position,and least number of employees belong to 'C' position.other position may has different counts,but 'SG' has the highest count followed closely by 'PF' #

# %% [markdown]
# ## 3.Find from which age group most of the employees belong to? ##

# %%
df["Age"]
# Out:
# 0      25
# 1      25
# 2      27
# 3      22
# 4      29
#        ..
# 453    26
# 454    24
# 455    26
# 456    26
# 457    25
# Name: Age, Length: 458, dtype: int64

# %%
df["Age"].nunique()
# Out:
# 22

# %%
df["Age"].value_counts()
# Out:
# Age
# 24    47
# 25    46
# 27    41
# 23    41
# 26    36
# 28    31
# 30    31
# 29    28
# 22    26
# 31    22
# 20    19
# 21    19
# 33    14
# 32    13
# 34    10
# 36    10
# 35     9
# 37     4
# 38     4
# 40     3
# 39     2
# 19     2
# Name: count, dtype: int64

# %%
plt.figure(figsize=(11,6))
sns.countplot(x='Age',data=df,hue='Age',palette='viridis')
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %% [markdown]
# #### Most employees are belong to the age group of 20-30.Most of the employees are falling under the age of '24'.There are 47 employees belong to the age of 24 in BC Acompany.least count is in the age group of 10-20.The countplot is used to represent the occurrence(count) of the observation present in the categorical variable. it uses the concept of a bar chart for the visual depiction.#

# %% [markdown]
# ## 4.Find out under which team and position,spending in terms of salary is high? ##

# %%
x=df['Salary'].mean()
df['Salary'].fillna(x,inplace=True)
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     179     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     171     235
# 2     John Holland  Boston Celtics      30       SG   27     176     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     175     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     173     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     174     203
# 454      Raul Neto       Utah Jazz      25       PG   24     178     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     170     256
# 456    Jeff Withey       Utah Jazz      24        C   26     151     231
# 457       Priyanka       Utah Jazz      34        C   25     165     231
#
#                College        Salary
# 0                Texas  7.730337e+06
# ...

# %%
data=df[['Team','Position','Salary']]
data
# Out:
#                Team Position        Salary
# 0    Boston Celtics       PG  7.730337e+06
# 1    Boston Celtics       SF  6.796117e+06
# 2    Boston Celtics       SG  4.833970e+06
# 3    Boston Celtics       SG  1.148640e+06
# 4    Boston Celtics       PF  5.000000e+06
# ..              ...      ...           ...
# 453       Utah Jazz       PG  2.433333e+06
# 454       Utah Jazz       PG  9.000000e+05
# 455       Utah Jazz        C  2.900000e+06
# 456       Utah Jazz        C  9.472760e+05
# 457       Utah Jazz        C  9.472760e+05
#
# [458 rows x 3 columns]

# %%
salary = data.groupby(['Team', 'Position'])['Salary'].sum().reset_index()
highest_spending = team_position_salary.loc[salary['Salary'].idxmax()]

highest_spending
# Out:
# Team        Los Angeles Lakers
# Position                    SF
# Salary              31866445.0
# Name: 67, dtype: object

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(15,5))
sns.boxplot(x='Team',y='Salary',hue='Position',data=df)
plt.xlabel('Team')
plt.ylabel('Salary')
plt.title('spending in terms of high salary')
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# ##### The Los Angeles Lakers spend the highest in terms of salary and it is about 31866445 with the position 'SF'.The above boxplot illustrates the salary distribution across different positions within each team in the dataset.it shows the distribution of quantitative data in a way that facilitates comparisons between variables or across levels of categorical variable. #

# %% [markdown]
# ## 5.Find if there is any correlation between age and salary,represent it visually. ##

# %%
df1=df[['Age','Salary']]
df1
# Out:
#      Age        Salary
# 0     25  7.730337e+06
# 1     25  6.796117e+06
# 2     27  4.833970e+06
# 3     22  1.148640e+06
# 4     29  5.000000e+06
# ..   ...           ...
# 453   26  2.433333e+06
# 454   24  9.000000e+05
# 455   26  2.900000e+06
# 456   26  9.472760e+05
# 457   25  9.472760e+05
#
# [458 rows x 2 columns]

# %%
corr=df1.corr()
print(corr)
plt.figure(figsize=(7,6))
sns.heatmap(df[['Age','Salary']].corr(),annot=True,cmap='Greens')
plt.title('Correlation between Age and salary')
plt.show()
# Out:
#             Age   Salary
# Age     1.00000  0.21117
# Salary  0.21117  1.00000

# %% [markdown]
# ##### The correlation shows the relationship between "Age" and 'Salary'.Here heatmap is used to plot the data that shows the magnitude of a certain phenomenon in the form of colors.cmap is the list of colors,optional.The value of 1.00000 along the diagonal represents the correlation of a variable with itself,which is always 1.it indicates positive correlaton.The correlation of 0.214009 is positive but weak relationship between age and salary.By analysing the above heatmap we can conclude that the employees in the age group of 30-40 years have the highest salary.It is showing that as the age increases the salary also increases ##
